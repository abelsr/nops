# %%
from pathlib import Path

import h5py
import torch
from scipy.io import loadmat
import matplotlib.pyplot as plt

# %%
data_path = Path("/home/abelsr/Proyects/Deep-Learning/nops/NavierStokes_V1e-5_N1200_T20.mat")

# %%
data_mat = loadmat(str(data_path))
data_mat.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'a', 'u', 't'])

# %%
u = data_mat["u"]

# %%
u.shape
# Out:
# (1200, 64, 64, 20)

# %%
u_torch = torch.from_numpy(u)
u_torch.shape, type(u_torch)
# Out:
# (torch.Size([1200, 64, 64, 20]), torch.Tensor)

# %%
torch.save(u_torch, "navier_stokes_v1e-3_N1200_T20.pt")
