# %%
from pathlib import Path

import torch
import matplotlib.pyplot as plt

# %%
data = torch.load('/home/abelsr/Proyects/Deep-Learning/nops/navier_stokes.pt')
print(data['a'].shape)
print(data['u'].shape)
print(data['t'].shape)
# Out:
# torch.Size([2048, 64, 64])
# torch.Size([2048, 64, 64, 10])
# torch.Size([10])

# %%
data_u = data['u']  # (samples, time, x, y, features)
sample_idx = 3
time_idx = -1
u_sample = data_u[sample_idx, :, :, time_idx].numpy()
plt.imshow(u_sample, cmap='jet')
plt.colorbar()
plt.title(f'Velocity field at time index {time_idx} for sample {sample_idx}')
plt.show()
