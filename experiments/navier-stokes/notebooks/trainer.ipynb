# %% [markdown]
# # Training Navier Stokes with nops

# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), os.pardir)))

from src.model import NavierStokesFNO
from data.ns_loader import NavierStokesDatasetHF

# %%
import hydra
from omegaconf import DictConfig, OmegaConf

@hydra.main(version_base=None, config_path="configs", config_name="config")
def main(cfg: DictConfig) -> None:
    # 1. Puedes ver la configuración completa en consola
    print(OmegaConf.to_yaml(cfg))
    
    # 2. Acceder a los parámetros usando sintaxis de atributos (dot notation)
    print(f"Entrenando {cfg.modelo.nombre} en {cfg.device}...")
    print(f"Learning rate: {cfg.entrenamiento.lr}")
    print(f"Semilla aleatoria: {cfg.seed}")
    
    # --- Aquí iría tu lógica de PyTorch / TensorFlow / JAX ---
    # modelo = mi_funcion_crear_modelo(cfg.modelo.nombre, cfg.modelo.num_clases)
    # optimizer = instantiate_optimizer(cfg.entrenamiento.optimizer, lr=cfg.entrenamiento.lr)
    
if __name__ == "__main__":
    main()
# Out:
# usage: ipykernel_launcher.py [--help] [--hydra-help] [--version]
#                              [--cfg {job,hydra,all}] [--resolve]
#                              [--package PACKAGE] [--run] [--multirun]
#                              [--shell-completion] [--config-path CONFIG_PATH]
#                              [--config-name CONFIG_NAME]
#                              [--config-dir CONFIG_DIR]
#                              [--experimental-rerun EXPERIMENTAL_RERUN]
#                              [--info [{all,config,defaults,defaults-tree,plugins,searchpath}]]
#                              [overrides ...]
# ipykernel_launcher.py: error: unrecognized arguments: --f=/run/user/1000/jupyter/runtime/kernel-v3023b9ba00a7f47eccca8f93064462a8bef6245dc.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
